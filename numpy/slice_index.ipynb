# %% [markdown]
# # NumPy索引

# %% [markdown]
# ## 导入NumPy

# %% [markdown]
# ## 创建数组
# 数组如下图所示：
# ![arr](images/arr.png)

# %%
##keep
a = np.array([1, 2, 3, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1])

# %% [markdown]
# ## 布尔索引
# 找出数组a中所有大于5的元素。

# %% [markdown]
# ## 布尔索引赋值
# 将数组a中所有3和5之间（包括3和5）的值设置为0。

# %%
##keep
# 重置数组a
a = np.array([1, 2, 3, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1])

# %% [markdown]
# ## np.where
# 将数组a中大于等于5的元素设置为1，小于5的元素设置为0。

# %% [markdown]
# ## np.clip
# 将数组a中所有大于5的元素设置为5，所有小于3的元素设置为3。

# %% [markdown]
# ## np.arange
# 创建从1开始到10，且步长为1的单调数组a。

# %% [markdown]
# ## 选出所有的奇数（切片语法）

# %% [markdown]
# ## 选出下标为1，3，4的元素（花式索引）

# %% [markdown]
# ## 排除最后一个元素

# %% [markdown]
# ## 逆序（切片语法）
